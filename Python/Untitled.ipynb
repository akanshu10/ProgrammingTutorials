# %%
import cv2
first_frame = None
video = cv2.VideoCapture(0)
a = 1
while True:
    a = a+1
    check ,frame = video.read()
    print(check)
    print(frame)
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray,(21,21),0)
    if first_frame is None:
        first_frame = gray
        continue
    delta_frame = cv2.absdiff(first_frame , gray)
    thresh_delta = cv2.threshold(delta_frame, 30,255, cv2.THRESH_BINARY)[1]
    thresh_delta = cv2.dilate(thresh_delta , None ,iterations =0)
    (_,cnts,_) = cv2.findContours(thresh_delta.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    
    for counter in cnts:
        if cv2.contourArea(counter)<1000:
            continue
        (x,y,w,h) = cv2.boundingRect(counter)
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),3)
    
    cv2.imshow("frame",frame)
    cv2.imshow("capture",gray)
    cv2.imshow("delta",delta_frame)
    cv2.imshow("thresh",thresh_delta)
    
    key = cv2.waitKey(1)
    
    if (key == ord('q')):
        break;
video.release()
cv2.destroyAllWindows()
# Out:
# True
# [[[141 139 122]
#   [141 138 121]
#   [140 136 118]
#   ...
#   [140 151 122]
#   [139 151 121]
#   [139 152 121]]
#
#  [[139 138 119]
#   [139 138 118]
#   [140 138 118]
#   ...
#   [141 151 124]
#   [139 151 122]
#   [138 150 121]]
#
#  [[136 138 113]
#   [137 139 114]
#   [138 140 115]
#   ...
#   [140 150 126]
#   [139 150 125]
#   [139 149 123]]
#
#  ...
#
#  [[146 145  98]
#   [144 143  96]
#   [143 143  93]
#   ...
#   [ 68 102 128]
#   [ 69 102 127]
#   [ 69 102 125]]
#
#  [[145 145  92]
#   [143 143  90]
#   [141 142  87]
#   ...
#   [ 72 102 130]
#   [ 71 102 127]
#   [ 71 102 124]]
#
#  [[144 145  88]
#   [141 143  84]
#   [140 142  83]
#   ...
#   [ 74 102 129]
#   [ 73 102 127]
#   [ 72 102 124]]]
# True
# [[[147 138 122]
#   [147 138 122]
#   [146 137 120]
#   ...
#   [132 148 118]
#   [133 149 119]
#   [132 148 118]]
#
#  [[145 137 120]
#   [145 137 120]
#   [144 137 118]
#   ...
#   [134 149 121]
#   [134 149 122]
#   [134 149 122]]
#
#  [[142 138 117]
#   [142 138 116]
#   [141 137 114]
#   ...
#   [136 150 126]
#   [135 149 125]
#   [135 149 125]]
#
#  ...
#
#  [[147 146 103]
#   [147 146 103]
#   [147 145 104]
#   ...
#   [ 68 101 131]
#   [ 68 102 132]
#   [ 69 103 133]]
#
#  [[148 148 105]
#   [147 147 104]
#   [147 147 104]
#   ...
#   [ 69 101 130]
#   [ 69 102 131]
#   [ 69 102 131]]
#
#  [[148 149 105]
#   [146 148 103]
#   [146 148 103]
#   ...
#   [ 70 102 131]
#   [ 70 102 131]
#   [ 69 101 130]]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <module>
#      16 thresh_delta = cv2.threshold(delta_frame, 30,255, cv2.THRESH_BINARY)[1]
#      17 thresh_delta = cv2.dilate(thresh_delta , None ,iterations =0)
# ---> 18 (_,cnts,_) = cv2.findContours(thresh_delta.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
#      20 for counter in cnts:
#      21     if cv2.contourArea(counter)<1000:
#
# ValueError: not enough values to unpack (expected 3, got 2)
